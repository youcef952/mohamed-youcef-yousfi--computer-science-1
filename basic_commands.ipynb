# %%
# Task 1 :Assigning values to variables
my_integer = 10             # Integer
my_float = 3.14             # Floating-point number
my_string = "Hello, world!" # String

# Printing all variables on one line, separated by commas
print(my_integer, my_float, my_string)





# Task 2.1: Working with 'age' variable
age = 25                     # Integer assignment
print("Type of age (int):", type(age))  # Output: <class 'int'>

age = 25.0                   # Now changing to float
print("Type of age (float):", type(age))  # Output: <class 'float'>

# Task 2.2: Boolean variable
is_student = True            # Boolean value
print("Type of is_student:", type(is_student))  # Output: <class 'bool'>


# Task 3.1: Ask the user for their name and greet them
name = input("What is your name? ")
print("Hello,", name + "!")

# Task 3.2: Ask the user for their age and check voting eligibility
age = int(input("How old are you? "))
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote yet.")





# Task 4.1: Convert string to integer and print its square
num_str = input("Enter a number: ")
num_int = int(num_str)
print("The square of the number is:", num_int ** 2)

# Task 4.2: Convert string to float, multiply by 2, and print
float_str = "4.56"  # Example string
float_num = float(float_str)
print("4.56 multiplied by 2 is:", float_num * 2)






# Task 5: Arithmetic Operations

# Addition
add_result = 45 + 67
print("45 + 67 =", add_result)

# Subtraction
sub_result = 156 - 89
print("156 - 89 =", sub_result)

# Multiplication
mul_result = 12 * 7
print("12 * 7 =", mul_result)

# Division
div_result = 100 / 4
print("100 / 4 =", div_result)

# Modulus (remainder)
mod_result = 10 % 3
print("10 % 3 =", mod_result)

# Exponentiation
exp_result = 3 ** 4
print("3 ** 4 =", exp_result)



# Task 5: Arithmetic Operations

# Addition
add_result = 45 + 67
print("45 + 67 =", add_result)

# Subtraction
sub_result = 156 - 89
print("156 - 89 =", sub_result)

# Multiplication
mul_result = 12 * 7
print("12 * 7 =", mul_result)

# Division
div_result = 100 / 4
print("100 / 4 =", div_result)

# Modulus (remainder)
mod_result = 10 % 3
print("10 % 3 =", mod_result)

# Exponentiation
exp_result = 3 ** 4
print("3 ** 4 =", exp_result)




# Task 6.1: Comparison using fixed values
a = 10
b = 20

print("a == b:", a == b)   # False
print("a != b:", a != b)   # True
print("a < b:", a < b)     # True
print("a > b:", a > b)     # False
print("a <= b:", a <= b)   # True
print("a >= b:", a >= b)   # False

# Task 6.2: User input comparison
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

if num1 >= num2:
    print("The first number is greater than or equal to the second.")
else:
    print("The first number is less than the second.")

# Task 7.1: Check if number is >10 and <20 using 'and'
num = int(input("Enter a number: "))
if num > 10 and num < 20:
    print("The number is greater than 10 and less than 20.")
else:
    print("The number is NOT in the range (10, 20).")

# Task 7.2: Check if number is <5 or >50 using 'or'
num2 = int(input("Enter another number: "))
if num2 < 5 or num2 > 50:
    print("The number is either less than 5 or greater than 50.")
else:
    print("The number is between 5 and 50 (inclusive).")



# Task 8.1: Age check
age = int(input("Enter your age: "))
if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")

# Task 8.2: FizzBuzz logic
number = int(input("Enter a number: "))
if number % 3 == 0 and number % 5 == 0:
    print("FizzBuzz.")
elif number % 3 == 0:
    print("Fizz.")
elif number % 5 == 0:
    print("Buzz.")
else:
    print(number)


# Task 9.1: For loop from 1 to 10
print("Numbers from 1 to 10:")
for i in range(1, 11):
    print(i)

# Task 9.2: While loop for even numbers from 2 to 20
print("\nEven numbers from 2 to 20:")
i = 2
while i <= 20:
    print(i)
    i += 2

# Task 9.3: Numbers divisible by 4 up to n
n = int(input("\nEnter a number n: "))
print(f"Numbers from 1 to {n} that are divisible by 4:")
for i in range(1, n + 1):
    if i % 4 == 0:
        print(i)
